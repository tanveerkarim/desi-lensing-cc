# %% [markdown]
# This notebook tests the CMB Lensing mock produced from AbacusSummit

# %%
# %matplotlib inline

import numpy as np
import healpy as hp
import matplotlib.pyplot as plt
plt.style.use("seaborn-notebook")

# %%
data_nested = np.load("../data/abacus/cmb/kappa_nested.npy")
mask = np.load("../data/abacus/cmb/mask_ring.npy")

# %%
# reorder data to ring
data = hp.reorder(data_nested, n2r = True)

# %% [markdown]
# Look at the map

# %%
hp.mollview(data, nest= True, cmap = 'inferno')
# Out:
# /home/tanveer/anaconda3/lib/python3.7/site-packages/healpy/projaxes.py:907: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   newcm.set_over(newcm(1.0))
# /home/tanveer/anaconda3/lib/python3.7/site-packages/healpy/projaxes.py:908: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   newcm.set_under(bgcolor)
# ...

# %%
#good = 1, bad = 0
hp.mollview(mask, cmap = 'inferno')

# %% [markdown]
# Apply mask on the data.

# %%
lensingMap_planck_masked = hp.ma(lensingMap_planck_masked, badval = 0)
lensingMap_planck_masked.mask = np.logical_not(lensing_mask_bool_planck)
